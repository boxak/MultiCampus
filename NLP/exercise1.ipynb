# %%
install.packages("readxl")
# Out:
# Warning message:
# "package 'readxl' is in use and will not be installed"

# %%
library(readxl)

# %%
reading <- readxl::read_excel(path="../DictionaryData_xls/625576_50000.xls",
                              sheet=1,
                              col_names=TRUE)
# Out:
# Warning message in read_fun(path = enc2native(normalizePath(path)), sheet_i = sheet, :
# "Expecting logical in W1246 / R1246C23: got '愿<ec>슜援<ac> 媛袁몃줈 諛뺥엳<eb>떎
# 癒몃━瑜<bc> <eb>븙<ec>쑝濡<9c> <ed>뼢<ed>븳 梨<84> <eb>뼥<ec>뼱吏<eb>떎.'"Warning message in read_fun(path = enc2native(normalizePath(path)), sheet_i = sheet, :
# "Expecting logical in W1284 / R1284C23: got '愿<ec>슜援<ac> 媛<eb>굹<eb>떎<eb>씪瑜<bc> 諛곗슦<eb>떎
# <ec>뼱<eb>뼡 吏<ec>떇<ec>씠<eb>굹 湲곗닠<ec>쓣 諛곗슦<eb>뒗 <eb>뜲 寃⑥슦 湲곗큹瑜<bc> <ec>떆<ec>옉<ed>븯<eb>떎.'"Warning message in read_fun(path = enc2native(normalizePath(path)), sheet_i = sheet, :
# "Expecting logical in W1285 / R1285C23: got '愿<ec>슜援<ac> 媛<eb>굹<eb>떎<eb>씪瑜<bc> 諛곗슦<eb>떎
# <ec>뼱<eb>뼡 吏<ec>떇<ec>씠<eb>굹 湲곗닠<ec>쓣 諛곗슦<eb>뒗 <eb>뜲 寃⑥슦 湲곗큹瑜<bc> <ec>떆<ec>옉<ed>븯<eb>떎.'"Warning message in read_fun(path = enc2native(normalizePath(path)), sheet_i = sheet, :
# "Expecting logical in W1313 / R1313C23: got '愿<ec>슜援<ac> 愿<ec>슜援<ac> 媛<eb>궃(<ec>씠) <eb>뱾<eb>떎
# 媛<eb>궃<ed>븯寃<8c> <eb>릺<eb>떎.
#
# ...
