# %%
library('dplyr')
# Out:
# Warning message:
# "package 'dplyr' was built under R version 3.6.2"
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
library('xlsx')

# %%
data1 <- read.xlsx2("DATA_01_1.xlsx",sheetIndex=1,startRow=1,header=TRUE)

# %%
library(dplyr)

# %%
head(data1)
# Out:
#   품사 의미.번호
# 1 접사 002
# 2 어미 007
# 3 어미 009
# 4 어미 011
# 5 어미 006
# 6 어미 008
#   뜻풀이
# 1 그 말의 의미를 세게 만드는 접미사.
# 2 앞말이 관형어 구실을 하게 하고, 사건이나 행위가 과거 또는 말하는 이가 상정한 기준 시점보다 과거에 일어남을 나타내는 어미.
# 3 앞말이 관형어 구실을 하게 하고 현재의 상태를 나타내는 어미.
# 4 물음을 나타내는 종결 어미.
# 5 청자에 대한 명령을 나타내는 종결 어미. 나이가 든 어른이 아이에게 말할 때 ‘-너라’보다 친근감을 준다.
# 6 앞말이 관형어 구실을 하게 하고 사건이나 행위가 완료되어 그 상태가 유지되고 있음을 나타내는 어미.

# %%
###filter(df,numberOfMeaning==1) %>%
###    count(partsOfSpeech)
filter(data1,의미.번호=="001") %>%
    count(품사)
# Out:
#    품사      n
# 1  감·명        3
# 2  감탄사       24
# 3  관·명      121
# 4  관형사        6
# 5  대·감        2
# 6  대명사       13
# 7  동사       3976
# 8  명·부        2
# 9  명사      21093
# 10 부사       1139
# 11 어미       1875
# 12 의존 명사    20
# 13 접사         66
# 14 조사         16
# 15 품사 없음 18058
# 16 형용사     1456

# %%
install.packages("stringr")
# Out:
# package 'stringr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Jiwon Hwang\AppData\Local\Temp\RtmpaSPIol\downloaded_packages

# %%
library('stringr')
# Out:
# Warning message:
# "package 'stringr' was built under R version 3.6.2"

# %%
library(stringr)

# %%
뜻풀이.음절 <- vector()
뜻풀이.음절
# Out:
# logical(0)

# %%
size <- nrow(data1)
size
# Out:
# [1] 60000

# %%
for(i in 1:size){
    뜻풀이.음절 <- c(뜻풀이.음절,str_length(data1[i,3])-str_count(data1[i,3],' ')-str_count(data1[i,3],',')-str_count(data1[i,3],'\\(')-str_count(data1[i,3],'\\)')-str_count(data1[i,3],fixed("."))-str_count(data1[i,3],'‘')-str_count(data1[i,3],'’'))
}
# Out:
# Warning message in stri_length(string):
# "invalid UTF-8 byte sequence detected; try calling stri_enc_toutf8()"

# %%
length(뜻풀이.음절)
# Out:
# [1] 60000

# %%
head(뜻풀이.음절)
# Out:
# [1] 14 51 25 11 41 41

# %%
cbind(data1,뜻풀이.음절)
head(data1)
# Out:
#       품사      의미.번호
# 1     접사      002
# 2     어미      007
# 3     어미      009
# 4     어미      011
# 5     어미      006
# 6     어미      008
# 7     어미      005
# 8     어미      003
# 9     어미      002
# 10    어미      001
# 11    어미      001
# 12    품사 없음 001
# 13    어미      001
# 14    어미      002
# 15    어미      001
# 16    어미      001
# 17    어미      002
# 18    어미      003
# 19    어미      001
# 20    품사 없음 001
# 21    어미      001
# 22    어미      001
# 23    어미      001
# 24    어미      002
# 25    어미      001
# 26    어미      001
# 27    어미      002
# 28    어미      003
# 29    어미      004
# 30    어미      002
# ...   ...       ...
# 59971 품사 없음 001
# 59972 품사 없음 001
# 59973 품사 없음 001
# 59974 품사 없음 001
# 59975 품사 없음 001
# 59976 품사 없음 001
# 59977 품사 없음 001
# 59978 명사      007
# 59979 명사      009
# 59980 명사      005
# 59981 명사      006
# 59982 명사      001
# 59983 명사      008
# 59984 명사      004
# 59985 명사      003
# 59986 명사      002
# 59987 명사      001
# 59988 명사      001
# ...

# %%
install.packages("writexl")
# Out:
# package 'writexl' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Jiwon Hwang\AppData\Local\Temp\RtmpaSPIol\downloaded_packages

# %%
library('writexl')
# Out:
# Warning message:
# "package 'writexl' was built under R version 3.6.2"

# %%
writexl::write_xlsx(data1, path = "RefinedData001.xlsx")
